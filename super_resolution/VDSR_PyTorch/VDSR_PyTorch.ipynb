# %%
# !git clone https://github.com/pclubiitk/model-zoo.git
# %cd /content/model-zoo/super_resolution/VDSR_PyTorch
# Out:
# fatal: destination path 'model-zoo' already exists and is not an empty directory.
# /content/model-zoo/super_resolution/VDSR_PyTorch

# %%
# !wget https://cv.snu.ac.kr/research/VDSR/train_data.zip
# !unzip train_data.zip
# Out:
# --2020-07-05 05:05:09--  https://cv.snu.ac.kr/research/VDSR/train_data.zip
# Resolving cv.snu.ac.kr (cv.snu.ac.kr)... 147.46.116.247
# Connecting to cv.snu.ac.kr (cv.snu.ac.kr)|147.46.116.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41628740 (40M) [application/zip]
# Saving to: ‘train_data.zip’
#
# train_data.zip      100%[===================>]  39.70M  10.5MB/s    in 4.0s
#
# 2020-07-05 05:05:14 (9.88 MB/s) - ‘train_data.zip’ saved [41628740/41628740]
#
# Archive:  train_data.zip
#    creating: 291/
#   inflating: 291/000t1.bmp
#   inflating: 291/000t10.bmp
#   inflating: 291/000t11.bmp
#   inflating: 291/000t12.bmp
#   inflating: 291/000t13.bmp
#   inflating: 291/000t14.bmp
#   inflating: 291/000t15.bmp
#   inflating: 291/000t16.bmp
#   inflating: 291/000t17.bmp
#   inflating: 291/000t18.bmp
#   inflating: 291/000t19.bmp
#   inflating: 291/000t2.bmp
#   inflating: 291/000t20.bmp
#   inflating: 291/000t21.bmp
#   inflating: 291/000t22.bmp
# ...

# %%
# %run dataset.py --dir ./91/ --out_dir train.h5
# Out:
# Streaming output truncated to the last 5000 lines.
# (7502, 41, 41) (7502, 41, 41)
# 7502
# (7503, 41, 41) (7503, 41, 41)
# 7503
# (7504, 41, 41) (7504, 41, 41)
# 7504
# (7505, 41, 41) (7505, 41, 41)
# 7505
# (7506, 41, 41) (7506, 41, 41)
# 7506
# (7507, 41, 41) (7507, 41, 41)
# 7507
# (7508, 41, 41) (7508, 41, 41)
# 7508
# (7509, 41, 41) (7509, 41, 41)
# 7509
# (7510, 41, 41) (7510, 41, 41)
# 7510
# (7511, 41, 41) (7511, 41, 41)
# 7511
# (7512, 41, 41) (7512, 41, 41)
# 7512
# (7513, 41, 41) (7513, 41, 41)
# 7513
# (7514, 41, 41) (7514, 41, 41)
# 7514
# (7515, 41, 41) (7515, 41, 41)
# 7515
# (7516, 41, 41) (7516, 41, 41)
# 7516
# (7517, 41, 41) (7517, 41, 41)
# 7517
# (7518, 41, 41) (7518, 41, 41)
# 7518
# (7519, 41, 41) (7519, 41, 41)
# 7519
# (7520, 41, 41) (7520, 41, 41)
# 7520
# (7521, 41, 41) (7521, 41, 41)
# 7521
# (7522, 41, 41) (7522, 41, 41)
# 7522
# (7523, 41, 41) (7523, 41, 41)
# 7523
# (7524, 41, 41) (7524, 41, 41)
# 7524
# (7525, 41, 41) (7525, 41, 41)
# 7525
# ...

# %%
# %run main.py --train_data train.h5 --cuda
# Out:
# => use gpu id: '0'
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch[1](50/79): Loss: 797.6009521484
# Epoch[2](50/79): Loss: 746.8321533203
# Checkpoint saved to checkpoint/model_epoch_2.pth
# Epoch[3](50/79): Loss: 593.0130615234
# Epoch[4](50/79): Loss: 535.3453979492
# Checkpoint saved to checkpoint/model_epoch_4.pth
# Epoch[5](50/79): Loss: 708.9005126953
# Epoch[6](50/79): Loss: 731.2194824219
# Checkpoint saved to checkpoint/model_epoch_6.pth
# Epoch[7](50/79): Loss: 612.4187011719
# Epoch[8](50/79): Loss: 538.8005371094
# Checkpoint saved to checkpoint/model_epoch_8.pth
# Epoch[9](50/79): Loss: 637.6755371094
# Epoch[10](50/79): Loss: 645.7893676758
# Checkpoint saved to checkpoint/model_epoch_10.pth
# Epoch[11](50/79): Loss: 582.8845214844
# Epoch[12](50/79): Loss: 632.8742675781
# ...
