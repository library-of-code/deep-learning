# %% [markdown]
# **Cloning the Repo**

# %%
# !git clone https://github.com/pclubiitk/model-zoo.git
# %cd /content/model-zoo/generative_models/cGAN_PyTorch
# Out:
# Cloning into 'model-zoo'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 526 (delta 0), reused 0 (delta 0), pack-reused 523
# Receiving objects: 100% (526/526), 40.99 MiB | 10.32 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# /content/model-zoo/generative_models/cGAN_PyTorch

# %%
# %run main.py --ndata 'mnist' --epochs 100
# Out:
# ...
# Extracting ./content/MNIST/raw/train-images-idx3-ubyte.gz to ./content/MNIST/raw
# ...
# Extracting ./content/MNIST/raw/train-labels-idx1-ubyte.gz to ./content/MNIST/raw
# ...
# Extracting ./content/MNIST/raw/t10k-images-idx3-ubyte.gz to ./content/MNIST/raw
# ...
# Extracting ./content/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./content/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# /content/model-zoo/generative_models/cGAN_PyTorch/model.py:71: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(m.weight)
# ...
